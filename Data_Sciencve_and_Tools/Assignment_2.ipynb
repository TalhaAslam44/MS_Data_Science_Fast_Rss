# %% [markdown]
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Life Cycle of the Project</div>

# %% [markdown]
# <div style="font-size: 14px; font-family: Verdana; border: 2px solid #ccc; background-color: #F5F5F5; padding: 10px; border-radius: 10px; margin-bottom: 20px; position: relative;">
#
#   <span style="color: #FF5733; font-weight: bold;">Steps to be Performed</span>
#   <ol>
#     <li><a href="#1">Introduction</a></li>
#     <li><a href="#2">About the Dataset </a></li>
#     <li><a href="#3">Importing Libraries</a></li>
#     <li><a href="#4">Data Cleaning 🧹</a></li>
#     <li><a href="#5">EDA 📊</a></li>
#     <li><a href="#6">Text Preprocessing ✍️</a></li>
#   </ol>
# </div>

# %% [markdown]
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">1. Introduction</div>

# %% [markdown]
# <h1 style="font-family: 'sans-serif'; font-weight: bold; text-align: left; color: white;">Author: Talha Aslam</h1>
#
# [![Gmail](https://img.shields.io/badge/Gmail-Contact%20Me-red?style=for-the-badge&logo=gmail)](ranatalha30055@gmail.com)
#
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/ranatalha71)
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/TalhaAslam44)
#
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](www.linkedin.com/in/talha-aslam-2693661b7)

# %% [markdown]
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">2. About the Dataset
# </div>
#
#
# ## Description:
#
# The sinking of the Titanic is one of the most infamous shipwrecks in history.
#
# On April 15, 1912, during her maiden voyage, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg. Unfortunately, there weren’t enough lifeboats for everyone on board, resulting in the death of 1502 out of 2224 passengers and crew.
#
# While there was some element of luck involved in surviving, it seems some groups of people were more likely to survive than others. Let's find out the factors which help to survive.

# %% [markdown]
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">3. Importing Libraries</div>

# %%
# Importing the liberaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">4. Loading and Understanding the Dataset</div>

# %%
# Importing the titanic dataset
df = sns.load_dataset('titanic')

# %%
# Set the maximum number of rows displayed
pd.set_option('display.max_rows', 100)

# Set the maximum number of columns displayed
pd.set_option('display.max_columns', 100)

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">5. Description of Dataset</div>

# %%
df.shape
# Out:
# (891, 15)

# %% [markdown]
# ---
# ### Observation
#
# - The train file has 891 Rows and 12 Columns

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
#see a sample of the dataset to get an idea of the variables
df.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked   class  \
# 149         0       2    male  42.0      0      0  13.000        S  Second
# 723         0       2    male  50.0      0      0  13.000        S  Second
# 579         1       3    male  32.0      0      0   7.925        S   Third
# 624         0       3    male  21.0      0      0  16.100        S   Third
# 290         1       1  female  26.0      0      0  78.850        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 149    man        True  NaN  Southampton    no   True
# 723    man        True  NaN  Southampton    no   True
# 579    man        True  NaN  Southampton   yes   True
# 624    man        True  NaN  Southampton    no   True
# 290  woman       False  NaN  Southampton   yes   True

# %% [markdown]
# ---
# ### Observations
#
# - `Numerical Features`: Age (Continuous), Fare (Continuous), SibSp (Discrete), Parch (Discrete)
# - `Categorical Features`: Survived, Sex, Embarked, Pclass
# - `Alphanumeric Features`: Ticket, Cabin
#
# What are the data types for each feature?
#
#
# - Survived: int
# - Pclass: int
# - Name: string
# - Sex: string
# - Age: float
# - SibSp: int
# - Parch: int
# - Ticket: string
# - Fare: float
# - Cabin: string
# - Embarked: string
#
# Now that we have an idea of what kinds of features we're working with, we can see how much information we have about each of them.

# %%
# FOr more info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# For all column names 
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# ---
# ### Observations
#
# **Variable Notes pclass** : A proxy for socio-economic status (SES)
#
# 1. 1st = Upper
# 2. 2nd = Middle
# 3. 3rd = Lower age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5 sibsp: The dataset defines family relations in this way...
#
# `Sibling` = brother, sister, stepbrother, stepsister
#
# `Spouse` = husband, wife (mistresses and fiancés were ignored)
#
# `parch:` The dataset defines family relations in this way...
#
# `Parent` = mother, father Child = daughter, son, stepdaughter, stepson
#
# Some children travelled only with a nanny, therefore parch=0 for them.

# %%
#see a summary of the training dataset
df.describe(include = "all")
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# count   891.000000      889    891  891        891  203          889   891
# unique         NaN        3      3    3          2    7            3     2
# top            NaN        S  Third  man       True    C  Southampton    no
# freq           NaN      644    491  537        537   59          644   549
# mean     32.204208      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# std      49.693429      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# min       0.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 25%       7.910400      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 50%      14.454200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 75%      31.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# max     512.329200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
#
#        alone
# count    891
# unique     2
# top     True
# freq     537
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN

# %% [markdown]
# ---
# ### Observations
#
# - There are a total of 891 passengers in our training set.
# - The Age feature is missing approximately 19.8% of its values. I'm guessing that the Age feature is pretty important to survival, so we should probably attempt - to fill these gaps.
# - The Cabin feature is missing approximately 77.1% of its values. Since so much of the feature is missing, it would be hard to fill in the missing values. We'll  probably drop these values from our dataset.
# - The Embarked feature is missing 0.22% of its values, which should be relatively harmless.

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">6. Dealing With Missing Values</div>

# %%
display(df.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ---
# ### Observations
#
# - We have Missing values in our Dataset.
# - Let's visualize it further.

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="Blues_r")
# Out:
# <Axes: >

# %% [markdown]
# - Another way for heat map we can use

# %%
plt.figure(figsize=(18,16))
sns.heatmap(df.isnull(), annot=True)
plt.show()

# %% [markdown]
# ---
# ### Observations
#
# - All the white strips in Age and Cabin columns shows the Missing Values.
# - We need to remove them or impute them.

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 0 50% 0 50% / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# Imputing Missing values
# </div>

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
display(df['Age'].isnull().sum())
print("\n")
display(df['Age'].isnull().sum())
# Out:
# np.int64(0)
# np.int64(0)

# %%
df = df.drop('deck', axis=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked
# 0        1      0         A/5 21171   7.2500        S
# 1        1      0          PC 17599  71.2833        C
# 2        0      0  STON/O2. 3101282   7.9250        S
# 3        1      0            113803  53.1000        S
# 4        0      0            373450   8.0500        S
# ..     ...    ...               ...      ...      ...
# 886      0      0            211536  13.0000        S
# 887      0      0            112053  30.0000        S
# 888      1      2        W./C. 6607  23.4500        S
# 889      0      0            111369  30.0000        C
# 890      0      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df['fare'] = df['fare'].fillna(df['fare'].mean())

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)

# %%
display(df.isnull().sum())
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
plt.figure(figsize=(18,16))
sns.heatmap(df.isnull(), annot=True)
plt.show()

# %% [markdown]
# ---
# ### Observations
#
# - We have removed and Filled all the missing values.
# - Let's Move to Data Visualization

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">7. Data Visualization</div>

# %%
plt.figure(figsize=(8,8))
df.dtypes.value_counts().plot.pie(autopct='%0.2f%%')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.set_style("whitegrid")
sns.countplot(data=df, y="embarked", order=df['embarked'].value_counts().index[0:115],hue='embarked' )
# Out:
# <Axes: xlabel='count', ylabel='embarked'>

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# Sex Feature
# </div>

# %%
plt.figure(figsize=(8,6))
plt.grid(True)
plt.bar(list(df['survived'].value_counts().keys()), list(df['survived'].value_counts()), color=('#1F77B4', '#FF7F0E'))
plt.title("Num of survived People")
plt.show()

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# For bar plot of survival by sex
sns.set_style("whitegrid")
sns.barplot(x="sex", y="survived", data=df, hue='sex')

#print percentages of females vs. males that survive
print("Percentage of females who survived:", df["survived"][df["sex"] == 'female'].value_counts(normalize = True)[1]*100)

print("Percentage of males who survived:", df["survived"][df["sex"] == 'male'].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of females who survived: 74.20382165605095
# Percentage of males who survived: 18.890814558058924

# %% [markdown]
# ---
# ### Observations
#
# - Females Survived more then the Male who were travelling in Titanic.

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# P-Class Feature
# </div>

# %%
# for bar plot of survival by Pclass
sns.set_style("whitegrid")
sns.barplot(x="pclass", y="survived", data=df,hue='pclass')

#print percentage of people by Pclass that survived
print("Percentage of Pclass = 1 who survived:", round(df["survived"][df["pclass"] == 1].value_counts(normalize = True)[1]*100, 2))

print("Percentage of Pclass = 2 who survived:", round(df["survived"][df["pclass"] == 2].value_counts(normalize = True)[1]*100, 2))

print("Percentage of Pclass = 3 who survived:", round(df["survived"][df["pclass"] == 3].value_counts(normalize = True)[1]*100, 2))
# Out:
# Percentage of Pclass = 1 who survived: 62.96
# Percentage of Pclass = 2 who survived: 47.28
# Percentage of Pclass = 3 who survived: 24.24

# %% [markdown]
# ---
# ### Observartions
#
# - People with higher socioeconomic class has higher rate of survival. (62.9% vs. 47.3% vs. 24.2%)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# SibSp Feature
# </div>

# %%
# for bar plot (SibSp vs. survival)
sns.set_style("whitegrid")
sns.barplot(x="sibsp", y="survived", data=df, palette="plasma")

#I won't be printing individual percent values for all of these.
print("Percentage of sibsp = 0 who survived:", round(df["survived"][df["sibsp"] == 0].value_counts(normalize = True)[1]*100, 2))

print("Percentage of sibsp = 1 who survived:", round(df["survived"][df["sibsp"] == 1].value_counts(normalize = True)[1]*100, 2))

print("Percentage of sibsp = 2 who survived:", round(df["survived"][df["sibsp"] == 2].value_counts(normalize = True)[1]*100, 2))
# Out:
# Percentage of sibsp = 0 who survived: 34.54
# Percentage of sibsp = 1 who survived: 53.59
# Percentage of sibsp = 2 who survived: 46.43

# %% [markdown]
# ---
# ### Observation
#
# - In general, people with more siblings or spouses aboard were less likely to survive.
# - However, contrary to expectations, people with no siblings or spouses were less to likely to survive than those with one or two. (34.5% vs 53.4% vs. 46.4%)

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# Parch Feature
# </div>

# %%
# For bar plot (Parch vs. survival)
sns.set_style("whitegrid")
sns.barplot(x="parch", y="survived", data=df, hue='parch')
plt.show()

# %% [markdown]
# ---
# ### Observation
#
# - People with less than four parents or children aboard are more likely to survive than those with four or more.
# - Again, people traveling alone are less likely to survive than those with 1-3 parents or children.

# %%
# Let's check survival rate on pclass
df.groupby('pclass')['survived'].value_counts()
# Out:
# pclass  survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x = 'survived', hue = 'pclass',color='Red', data = df)
plt.xlabel('survived')
plt.ylabel('Count')
plt.title('Bar plot of Survived or Not Passengers on the basis of Class')
plt.show()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
#  Emabrked Feature
# </div>

# %%
# Count the number of passengers for each embarkation port
embarked_counts = df['embarked'].value_counts()

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))
colors = plt.cm.viridis(np.linspace(0, 1, len(embarked_counts)))
embarked_counts.plot(kind='bar', ax=ax, color=colors)  # Apply the Viridis color palette
ax.set_title('Distribution of Passengers by Embarkation Port')
ax.set_xlabel('Embarkation Port')
ax.set_ylabel('Number of Passengers')
plt.show()

# %%
#now we need to fill in the missing values in the Embarked feature
print("Number of people embarking in Southampton (S):")
southampton = df[df["embarked"] == "S"].shape[0]
print(southampton)

print("Number of people embarking in Cherbourg (C):")
cherbourg = df[df["embarked"] == "C"].shape[0]
print(cherbourg)

print("Number of people embarking in Queenstown (Q):")
queenstown = df[df["embarked"] == "Q"].shape[0]
print(queenstown)
# Out:
# Number of people embarking in Southampton (S):
# 646
# Number of people embarking in Cherbourg (C):
# 168
# Number of people embarking in Queenstown (Q):
# 77

# %% [markdown]
# - It's clear that the majority of people embarked in Southampton (S).

# %%
plt.figure(figsize=(10, 8))
sns.countplot(data=df, y="embarked", order=df['embarked'].value_counts().index[0:15], hue='embarked')
# Out:
# <Axes: xlabel='count', ylabel='embarked'>

# %%
bl_col = df.select_dtypes(include=('boolean'))
int_col = df.select_dtypes(include=('int')).columns
str_col = df.select_dtypes(include=('object')).columns
df.hist(figsize=(18, 10))
plt.show()

# %%
display(df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %% [markdown]
# - Let's dive into more Visualization

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# Age Feature
# </div>

# %%
#Historgram
plt.figure(figsize=(5,5))
plt.hist(df['age'])
plt.title("AGE")
plt.show()

#Bar
plt.figure(figsize=(5,5))
plt.bar(list(df['age'].value_counts().keys()), list(df['age'].value_counts()))
plt.title("Age")
plt.ylabel("Num of Passengers")
plt.show()

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">8. Label Encoding</div>

# %%
bl_col = df.select_dtypes(include=('boolean'))
int_col = df.select_dtypes(include=('int')).columns
str_col = df.select_dtypes(include=('object')).columns

str_col_1 = df.select_dtypes(include=('object')).columns

# %%
display(str_col)
# Out:
# Index(['sex', 'embarked', 'who', 'embark_town', 'alive'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

L_e = LabelEncoder()

# %%
for col in str_col:
    df[col] = L_e.fit_transform(df[col].astype('str'))

# %%
for col in str_col_1:
    df[col] = L_e.fit_transform(df[col].astype('str'))

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">9.. Target and Features</div>

# %%
x = df.drop(['survived'], axis=True)

# %%
y = df[["survived"]]

# %%
x
# Out:
#      pclass  sex        age  sibsp  parch     fare  embarked   class  who  \
# 0         3    1  22.000000      1      0   7.2500         2   Third    1
# 1         1    0  38.000000      1      0  71.2833         0   First    2
# 2         3    0  26.000000      0      0   7.9250         2   Third    2
# 3         1    0  35.000000      1      0  53.1000         2   First    2
# 4         3    1  35.000000      0      0   8.0500         2   Third    1
# ..      ...  ...        ...    ...    ...      ...       ...     ...  ...
# 886       2    1  27.000000      0      0  13.0000         2  Second    1
# 887       1    0  19.000000      0      0  30.0000         2   First    2
# 888       3    0  29.699118      1      2  23.4500         2   Third    2
# 889       1    1  26.000000      0      0  30.0000         0   First    1
# 890       3    1  32.000000      0      0   7.7500         1   Third    1
#
#      adult_male  embark_town  alive  alone
# 0          True            2      0  False
# 1         False            0      1  False
# 2         False            2      1   True
# 3         False            2      1  False
# 4          True            2      0   True
# ..          ...          ...    ...    ...
# 886        True            2      0   True
# 887       False            2      1   True
# 888       False            2      0  False
# 889        True            0      1   True
# 890        True            1      0   True
#
# [891 rows x 13 columns]

# %%
y
# Out:
#      survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %% [markdown]
# - Now we will calculate coorealtion of x

# %%
x.drop(columns=['class']).corr()
# Out:
#                pclass       sex       age     sibsp     parch      fare  \
# pclass       1.000000  0.131900 -0.331339  0.083081  0.018443 -0.549500
# sex          0.131900  1.000000  0.084153 -0.114631 -0.245489 -0.182333
# age         -0.331339  0.084153  1.000000 -0.232625 -0.179191  0.091566
# sibsp        0.083081 -0.114631 -0.232625  1.000000  0.414838  0.159651
# parch        0.018443 -0.245489 -0.179191  0.414838  1.000000  0.216225
# fare        -0.549500 -0.182333  0.091566  0.159651  0.216225  1.000000
# embarked     0.162098  0.108262 -0.026749  0.068230  0.039798 -0.224719
# who         -0.196793 -0.639773  0.354507 -0.136003 -0.055682  0.146290
# adult_male   0.094035  0.908578  0.253236 -0.253586 -0.349943 -0.182024
# embark_town  0.157112  0.104057 -0.022239  0.066654  0.038322 -0.221226
# alive       -0.338481 -0.543351 -0.069809 -0.035322  0.081629  0.257307
# alone        0.135207  0.303646  0.179775 -0.584471 -0.583398 -0.271832
#
#              embarked       who  adult_male  embark_town     alive     alone
# pclass       0.162098 -0.196793    0.094035     0.157112 -0.338481  0.135207
# sex          0.108262 -0.639773    0.908578     0.104057 -0.543351  0.303646
# age         -0.026749  0.354507    0.253236    -0.022239 -0.069809  0.179775
# sibsp        0.068230 -0.136003   -0.253586     0.066654 -0.035322 -0.584471
# parch        0.039798 -0.055682   -0.349943     0.038322  0.081629 -0.583398
# fare        -0.224719  0.146290   -0.182024    -0.221226  0.257307 -0.271832
# embarked     1.000000 -0.064154    0.092526     0.998223 -0.167675  0.063532
# who         -0.064154  1.000000   -0.437532    -0.060177  0.325753  0.006540
# adult_male   0.092526 -0.437532    1.000000     0.088725 -0.557080  0.404744
# embark_town  0.998223 -0.060177    0.088725     1.000000 -0.163517  0.065610
# alive       -0.167675  0.325753   -0.557080    -0.163517  1.000000 -0.203367
# alone        0.063532  0.006540    0.404744     0.065610 -0.203367  1.000000

# %%
plt.figure(figsize=(18,16))
sns.heatmap(x.drop(columns=['class']).corr(), annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">9. Data Normalization and Standardization</div>

# %%
# Select numerical features
numerical_features = ['age', 'fare', 'sibsp', 'parch']

# %%
# Apply Standardization
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = StandardScaler()
df_standardized = df.copy()
df_standardized[numerical_features] = scaler.fit_transform(df[numerical_features])

# %%
# Apply Normalization
normalizer = MinMaxScaler()
df_normalized = df.copy()
df_normalized[numerical_features] = normalizer.fit_transform(df[numerical_features])

# %%
print(df_standardized.head())  # Standardized data
print(df_normalized.head())    # Normalized data
# Out:
#    survived  pclass  sex       age     sibsp     parch      fare  embarked  \
# 0         0       3    1 -0.592481  0.432793 -0.473674 -0.502445         2
# 1         1       1    0  0.638789  0.432793 -0.473674  0.786845         0
# 2         1       3    0 -0.284663 -0.474545 -0.473674 -0.488854         2
# 3         1       1    0  0.407926  0.432793 -0.473674  0.420730         2
# 4         0       3    1  0.407926 -0.474545 -0.473674 -0.486337         2
#
#    class  who  adult_male  embark_town  alive  alone
# 0  Third    1        True            2      0  False
# 1  First    2       False            0      1  False
# 2  Third    2       False            2      1   True
# 3  First    2       False            2      1  False
# 4  Third    1        True            2      0   True
#    survived  pclass  sex       age  sibsp  parch      fare  embarked  class  \
# 0         0       3    1  0.271174  0.125    0.0  0.014151         2  Third
# 1         1       1    0  0.472229  0.125    0.0  0.139136         0  First
# 2         1       3    0  0.321438  0.000    0.0  0.015469         2  Third
# 3         1       1    0  0.434531  0.125    0.0  0.103644         2  First
# 4         0       3    1  0.434531  0.000    0.0  0.015713         2  Third
#
#    who  adult_male  embark_town  alive  alone
# 0    1        True            2      0  False
# 1    2       False            0      1  False
# 2    2       False            2      1   True
# 3    2       False            2      1  False
# 4    1        True            2      0   True
