# %% [markdown]
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Life Cycle of the Project</div>

# %% [markdown]
# <div style="font-size: 14px; font-family: Verdana; border: 2px solid #ccc; background-color: #F5F5F5; padding: 10px; border-radius: 10px; margin-bottom: 20px; position: relative;">
#
#   <span style="color: #FF5733; font-weight: bold;">Steps to be Performed</span>
#   <ol>
#     <li><a href="#1">Introduction</a></li>
#     <li><a href="#2">About the Dataset </a></li>
#     <li><a href="#3">Importing Libraries</a></li>
#     <li><a href="#4">Data Cleaning 🧹</a></li>
#     <li><a href="#5">EDA 📊</a></li>
#     <li><a href="#6">Text Preprocessing ✍️</a></li>
#     <li><a href="#7">Model Training 🤖</a></li>
#     <li><a href="#8">Evaluation 📈</a></li>
#     <li><a href="#9">Conclusion 🎉</a></li>
#     <li><a href="#10">Author Message ✉️</a></li>
#   </ol>
# </div>

# %% [markdown]
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">1. Introduction</div>

# %% [markdown]
# <h1 style="font-family: 'sans-serif'; font-weight: bold; text-align: left; color: white;">Author: Talha Aslam</h1>
#
# [![Gmail](https://img.shields.io/badge/Gmail-Contact%20Me-red?style=for-the-badge&logo=gmail)](ranatalha30055@gmail.com)
#
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/ranatalha71)
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/TalhaAslam44)
#
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](www.linkedin.com/in/talha-aslam-2693661b7)

# %% [markdown]
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">2. About the Dataset
# </div>
#
#
# ## Description:
#
# The sinking of the Titanic is one of the most infamous shipwrecks in history.
#
# On April 15, 1912, during her maiden voyage, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg. Unfortunately, there weren’t enough lifeboats for everyone on board, resulting in the death of 1502 out of 2224 passengers and crew.
#
# While there was some element of luck involved in surviving, it seems some groups of people were more likely to survive than others. Let's find out the factors which help to survive.

# %% [markdown]
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">3. Importing Libraries</div>

# %%
# Importing the liberaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div style="text-align: center; background: #1ED760; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">4. Importing Machine learning Models</div>

# %%
# Install scikit-learn and xgboost
# %pip install scikit-learn xgboost

# Models for classification task
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
# Evaluation Metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">5. Loading and Understanding the Dataset</div>

# %%
train_file = pd.read_csv('./DataSets/train.csv')
test_file = pd.read_csv('./DataSets/test.csv')

# %%
# Set the maximum number of rows displayed
pd.set_option('display.max_rows', 100)

# Set the maximum number of columns displayed
pd.set_option('display.max_columns', 100)

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">6. Description of Dataset</div>

# %%
train_file.shape
# Out:
# (891, 12)

# %% [markdown]
# ---
# ### Observation
#
# - The train file has 891 Rows and 12 Columns

# %%
train_file.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#see a sample of the dataset to get an idea of the variables
train_file.sample(5)
# Out:
#      PassengerId  Survived  Pclass                      Name     Sex    Age  \
# 67            68         0       3  Crease, Mr. Ernest James    male  19.00
# 644          645         1       3    Baclini, Miss. Eugenie  female   0.75
# 514          515         0       3         Coleff, Mr. Satio    male  24.00
# 402          403         0       3  Jussila, Miss. Mari Aina  female  21.00
# 833          834         0       3    Augustsson, Mr. Albert    male  23.00
#
#      SibSp  Parch     Ticket     Fare Cabin Embarked
# 67       0      0  S.P. 3464   8.1583   NaN        S
# 644      2      1       2666  19.2583   NaN        C
# 514      0      0     349209   7.4958   NaN        S
# 402      1      0       4137   9.8250   NaN        S
# 833      0      0     347468   7.8542   NaN        S

# %% [markdown]
# ---
# ### Observations
#
# - `Numerical Features`: Age (Continuous), Fare (Continuous), SibSp (Discrete), Parch (Discrete)
# - `Categorical Features`: Survived, Sex, Embarked, Pclass
# - `Alphanumeric Features`: Ticket, Cabin
#
# What are the data types for each feature?
#
#
# - Survived: int
# - Pclass: int
# - Name: string
# - Sex: string
# - Age: float
# - SibSp: int
# - Parch: int
# - Ticket: string
# - Fare: float
# - Cabin: string
# - Embarked: string
#
# Now that we have an idea of what kinds of features we're working with, we can see how much information we have about each of them.

# %%
# FOr more info
train_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# For all column names 
train_file.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ---
# ### Observations
#
# **Variable Notes pclass** : A proxy for socio-economic status (SES)
#
# 1. 1st = Upper
# 2. 2nd = Middle
# 3. 3rd = Lower age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5 sibsp: The dataset defines family relations in this way...
#
# `Sibling` = brother, sister, stepbrother, stepsister
#
# `Spouse` = husband, wife (mistresses and fiancés were ignored)
#
# `parch:` The dataset defines family relations in this way...
#
# `Parent` = mother, father Child = daughter, son, stepdaughter, stepson
#
# Some children travelled only with a nanny, therefore parch=0 for them.

# %%
#see a summary of the training dataset
train_file.describe(include = "all")
# Out:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare Cabin Embarked
# ...

# %% [markdown]
# ---
# ### Observations
#
# - There are a total of 891 passengers in our training set.
# - The Age feature is missing approximately 19.8% of its values. I'm guessing that the Age feature is pretty important to survival, so we should probably attempt - to fill these gaps.
# - The Cabin feature is missing approximately 77.1% of its values. Since so much of the feature is missing, it would be hard to fill in the missing values. We'll  probably drop these values from our dataset.
# - The Embarked feature is missing 0.22% of its values, which should be relatively harmless.

# %%
train_file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_file.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">7. Dealing With Missing Values</div>

# %%
display(train_file.isnull().sum())
print("\n")
display(test_file.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ---
# ### Observations
#
# - We have Missing values in our Dataset.
# - Let's visualize it further.

# %%
sns.heatmap(train_file.isnull(),yticklabels=False,cbar=False,cmap="Blues_r")
# Out:
# <Axes: >

# %% [markdown]
# - Another way for heat map we can use

# %%
plt.figure(figsize=(18,16))
sns.heatmap(train_file.isnull(), annot=True)
plt.show()

# %% [markdown]
# ---
# ### Observations
#
# - All the white strips in Age and Cabin columns shows the Missing Values.
# - We need to remove them or impute them.

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 0 50% 0 50% / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# Imputing Missing values
# </div>

# %%
train_file['Age'] = train_file['Age'].fillna(train_file['Age'].mean())


test_file['Age'] = test_file['Age'].fillna(test_file['Age'].mean())

# %%
display(train_file['Age'].isnull().sum())
print("\n")
display(test_file['Age'].isnull().sum())
# Out:
# np.int64(0)
# np.int64(0)

# %%
train_file = train_file.drop('Cabin', axis=True)
test_file = test_file.drop('Cabin', axis=True)

# %%
train_file
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
test_file.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
test_file['Fare'] = test_file['Fare'].fillna(test_file['Fare'].mean())

# %%
test_file.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
train_file['Embarked'].fillna(train_file['Embarked'].mode()[0], inplace=True)

# %%
display(train_file.isnull().sum())
print("\n")
display(test_file.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
plt.figure(figsize=(18,16))
sns.heatmap(train_file.isnull(), annot=True)
plt.show()

# %% [markdown]
# ---
# ### Observations
#
# - We have removed and Filled all the missing values.
# - Let's Move to Data Visualization

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">8. Data Visualization</div>

# %%
plt.figure(figsize=(8,8))
train_file.dtypes.value_counts().plot.pie(autopct='%0.2f%%')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.set_style("whitegrid")
sns.countplot(data=train_file, y="Embarked", order=train_file['Embarked'].value_counts().index[0:115],hue='Embarked' )
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# Sex Feature
# </div>

# %%
plt.figure(figsize=(8,6))
plt.grid(True)
plt.bar(list(train_file['Survived'].value_counts().keys()), list(train_file['Survived'].value_counts()), color=('#1F77B4', '#FF7F0E'))
plt.title("Num of Survived People")
plt.show()

# %%
train_file['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# For bar plot of survival by sex
sns.set_style("whitegrid")
sns.barplot(x="Sex", y="Survived", data=train_file, hue='Sex')

#print percentages of females vs. males that survive
print("Percentage of females who survived:", train_file["Survived"][train_file["Sex"] == 'female'].value_counts(normalize = True)[1]*100)

print("Percentage of males who survived:", train_file["Survived"][train_file["Sex"] == 'male'].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of females who survived: 74.20382165605095
# Percentage of males who survived: 18.890814558058924

# %% [markdown]
# ---
# ### Observations
#
# - Females Survived more then the Male who were travelling in Titanic.

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# P-Class Feature
# </div>

# %%
# for bar plot of survival by Pclass
sns.set_style("whitegrid")
sns.barplot(x="Pclass", y="Survived", data=train_file,hue='Pclass')

#print percentage of people by Pclass that survived
print("Percentage of Pclass = 1 who survived:", round(train_file["Survived"][train_file["Pclass"] == 1].value_counts(normalize = True)[1]*100, 2))

print("Percentage of Pclass = 2 who survived:", round(train_file["Survived"][train_file["Pclass"] == 2].value_counts(normalize = True)[1]*100, 2))

print("Percentage of Pclass = 3 who survived:", round(train_file["Survived"][train_file["Pclass"] == 3].value_counts(normalize = True)[1]*100, 2))
# Out:
# Percentage of Pclass = 1 who survived: 62.96
# Percentage of Pclass = 2 who survived: 47.28
# Percentage of Pclass = 3 who survived: 24.24

# %% [markdown]
# ---
# ### Observartions
#
# - People with higher socioeconomic class has higher rate of survival. (62.9% vs. 47.3% vs. 24.2%)

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# SibSp Feature
# </div>

# %%
# for bar plot (SibSp vs. survival)
sns.set_style("whitegrid")
sns.barplot(x="SibSp", y="Survived", data=train_file, palette="plasma")

#I won't be printing individual percent values for all of these.

print("Percentage of SibSp = 0 who survived:", round(train_file["Survived"][train_file["SibSp"] == 0].value_counts(normalize = True)[1]*100, 2))

print("Percentage of SibSp = 1 who survived:", round(train_file["Survived"][train_file["SibSp"] == 1].value_counts(normalize = True)[1]*100, 2))

print("Percentage of SibSp = 2 who survived:", round(train_file["Survived"][train_file["SibSp"] == 2].value_counts(normalize = True)[1]*100, 2))
# Out:
# Percentage of SibSp = 0 who survived: 34.54
# Percentage of SibSp = 1 who survived: 53.59
# Percentage of SibSp = 2 who survived: 46.43

# %% [markdown]
# ---
# ### Observation
#
# - In general, people with more siblings or spouses aboard were less likely to survive.
# - However, contrary to expectations, people with no siblings or spouses were less to likely to survive than those with one or two. (34.5% vs 53.4% vs. 46.4%)

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# Parch Feature
# </div>

# %%
# For bar plot (Parch vs. survival)
sns.set_style("whitegrid")
sns.barplot(x="Parch", y="Survived", data=train_file, hue='Parch')
plt.show()

# %% [markdown]
# ---
# ### Observation
#
# - People with less than four parents or children aboard are more likely to survive than those with four or more.
# - Again, people traveling alone are less likely to survive than those with 1-3 parents or children.

# %%
# Let's check survival rate on pclass
train_file.groupby('Pclass')['Survived'].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x = 'Survived', hue = 'Pclass',color='Red', data = train_file)
plt.xlabel('Survived')
plt.ylabel('Count')
plt.title('Bar plot of Survived or Not Passengers on the basis of Class')
plt.show()

# %%
train_file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
#  Emabrked Feature
# </div>

# %%
# Count the number of passengers for each embarkation port
embarked_counts = train_file['Embarked'].value_counts()

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))
colors = plt.cm.viridis(np.linspace(0, 1, len(embarked_counts)))
embarked_counts.plot(kind='bar', ax=ax, color=colors)  # Apply the Viridis color palette
ax.set_title('Distribution of Passengers by Embarkation Port')
ax.set_xlabel('Embarkation Port')
ax.set_ylabel('Number of Passengers')
plt.show()

# %%
#now we need to fill in the missing values in the Embarked feature
print("Number of people embarking in Southampton (S):")
southampton = train_file[train_file["Embarked"] == "S"].shape[0]
print(southampton)

print("Number of people embarking in Cherbourg (C):")
cherbourg = train_file[train_file["Embarked"] == "C"].shape[0]
print(cherbourg)

print("Number of people embarking in Queenstown (Q):")
queenstown = train_file[train_file["Embarked"] == "Q"].shape[0]
print(queenstown)
# Out:
# Number of people embarking in Southampton (S):
# 646
# Number of people embarking in Cherbourg (C):
# 168
# Number of people embarking in Queenstown (Q):
# 77

# %% [markdown]
# - It's clear that the majority of people embarked in Southampton (S).

# %%
plt.figure(figsize=(10, 8))
sns.countplot(data=train_file, y="Ticket", order=train_file['Ticket'].value_counts().index[0:15],hue='Ticket')
# Out:
# <Axes: xlabel='count', ylabel='Ticket'>

# %%
bl_col = train_file.select_dtypes(include=('boolean'))
int_col = train_file.select_dtypes(include=('int')).columns
str_col = train_file.select_dtypes(include=('object')).columns
train_file.hist(figsize=(18, 10))
plt.show()

# %%
display(train_file.columns)
print("\n")
display(test_file.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# - Let's dive into more Visualization

# %%
sns.jointplot(data=train_file, x='Pclass', y='Survived')
sns.jointplot(data=train_file, x='Parch', y='Survived')
sns.jointplot(data=train_file, x='Age', y='Survived')
sns.jointplot(data=train_file, x='SibSp', y='Survived')

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: left; background: #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 22px; font-weight: bold; line-height: 1; border-radius: 50% 0 0 50% / 10px 0 0 10px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">
# Age Feature
# </div>

# %%
#Historgram
plt.figure(figsize=(5,5))
plt.hist(train_file['Age'])
plt.title("AGE")
plt.show()

#Bar
plt.figure(figsize=(5,5))
plt.bar(list(train_file['Age'].value_counts().keys()), list(train_file['Age'].value_counts()))
plt.title("Age")
plt.ylabel("Num of Passengers")
plt.show()

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">9. Label Encoding</div>

# %%
bl_col = train_file.select_dtypes(include=('boolean'))
int_col = train_file.select_dtypes(include=('int')).columns
str_col = train_file.select_dtypes(include=('object')).columns

str_col_1 = test_file.select_dtypes(include=('object')).columns

# %%
display(str_col)
print("\n")
display(str_col_1)
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Embarked'], dtype='object')
# Index(['Name', 'Sex', 'Ticket', 'Embarked'], dtype='object')

# %%
L_e = LabelEncoder()

# %%
for col in str_col:
    train_file[col] = L_e.fit_transform(train_file[col].astype('str'))

# %%
for col in str_col_1:
    test_file[col] = L_e.fit_transform(test_file[col].astype('str'))

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">10. Target and Features</div>

# %%
x = train_file.drop(['Survived'], axis=True)

# %%
y = train_file[["Survived"]]

# %%
x
# Out:
#      PassengerId  Pclass  Name  Sex        Age  SibSp  Parch  Ticket     Fare  \
# 0              1       3   108    1  22.000000      1      0     523   7.2500
# 1              2       1   190    0  38.000000      1      0     596  71.2833
# 2              3       3   353    0  26.000000      0      0     669   7.9250
# 3              4       1   272    0  35.000000      1      0      49  53.1000
# 4              5       3    15    1  35.000000      0      0     472   8.0500
# ..           ...     ...   ...  ...        ...    ...    ...     ...      ...
# 886          887       2   548    1  27.000000      0      0     101  13.0000
# 887          888       1   303    0  19.000000      0      0      14  30.0000
# 888          889       3   413    0  29.699118      1      2     675  23.4500
# 889          890       1    81    1  26.000000      0      0       8  30.0000
# 890          891       3   220    1  32.000000      0      0     466   7.7500
#
#      Embarked
# 0           2
# ...

# %%
y
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %% [markdown]
# - Now we will calculate coorealtion of x

# %%
x.corr()
# Out:
#              PassengerId    Pclass      Name       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.035144 -0.038559  0.042939  0.033207 -0.057527
# Pclass         -0.035144  1.000000  0.052831  0.131900 -0.331339  0.083081
# Name           -0.038559  0.052831  1.000000  0.020314  0.057466 -0.017230
# Sex             0.042939  0.131900  0.020314  1.000000  0.084153 -0.114631
# Age             0.033207 -0.331339  0.057466  0.084153  1.000000 -0.232625
# SibSp          -0.057527  0.083081 -0.017230 -0.114631 -0.232625  1.000000
# Parch          -0.001652  0.018443 -0.049105 -0.245489 -0.179191  0.414838
# Ticket         -0.056554  0.319869  0.047348  0.059372 -0.068848  0.079461
# Fare            0.012658 -0.549500 -0.049173 -0.182333  0.091566  0.159651
# Embarked        0.013128  0.162098 -0.006117  0.108262 -0.026749  0.068230
#
#                 Parch    Ticket      Fare  Embarked
# PassengerId -0.001652 -0.056554  0.012658  0.013128
# ...

# %%
plt.figure(figsize=(18,16))
sns.heatmap(x.corr(), annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">11. Splitting the Training Data</div>

# %% [markdown]
# `We will use part of our training data (33% in this case) to test the accuracy of our different models.`

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.33)

# %%
# Let's check the shape of X_train and X_test data
print(f"The shape of train data is {X_train.shape} anad test data is {X_test.shape}")
# Out:
# The shape of train data is (596, 10) anad test data is (295, 10)

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">12. Testing Different Models</div>

# %% [markdown]
# I will be testing the following models with my training data (got the list from here):
#
# - Logistic Regression
# - Support Vector Machines
# - Decision Tree Classifier
# - Random Forest Classifier
# - KNN or k-Nearest Neighbors
# - Gradient Boosting Classifier
# - AdaBoost Classifier
# - BeggingClassifier
# - XGB Classifier
#
# For each model, we set the model, fit it with 80% of our training data, predict for 20% of the training data and check the accuracy.

# %% [markdown]
# <a id="5"></a>
# <div style="text-align: left; background:  #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Model Builiding</div>

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier

lrc = LogisticRegression(solver = 'liblinear', penalty = 'l1')
svc = SVC(kernel= "sigmoid", gamma  = 1.0)
dtc = DecisionTreeClassifier(max_depth = 5)
knn = KNeighborsClassifier(n_neighbors = 5)
rfc = RandomForestClassifier(n_estimators = 50, random_state = 2 )
abc = AdaBoostClassifier(n_estimators = 50, random_state = 2)
gbc = GradientBoostingClassifier(n_estimators = 50, random_state = 2)
bc = BaggingClassifier(n_estimators = 50, random_state = 2)
xgb = XGBClassifier(n_estimators = 50, random_state = 2)

# %% [markdown]
# <a id="5"></a>
# <div style="text-align: left; background:  #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Dictionary of the Models</div>

# %%
clfs = {
    'LogisticRegression': lrc,
    'Support_Vector': svc,
    'DecisionTree': dtc,
    'Kneighbors': knn,
    'Random Forest': rfc,
    'AdaBoost': abc,
    'GradientBoost': gbc,
    'Beggin': bc,
    'XGB': xgb,
}

# %% [markdown]
# <a id="5"></a>
# <div style="text-align: left; background:  #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Train the Models</div>

# %%
from sklearn.metrics import accuracy_score, precision_score
def train_classifier(clfs, X_train, y_train, X_test, y_test):
    clfs.fit(X_train,y_train)
    y_pred = clfs.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    return accuracy , precision

# %% [markdown]
# <a id="5"></a>
# <div style="text-align: left; background:  #FF00CC; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Confusion Matrix</div>

# %%
def plot_confusion_matrix(cm, title):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(title)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# %% [markdown]
# <div style="text-align: center; background: #056559; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">13. Evaluate the Models</div>

# %%
from sklearn.metrics import confusion_matrix

accuracy_scores = []
precision_scores = []
for name, clf in clfs.items():
    current_accuracy, current_precision = train_classifier(clf, X_train, y_train, X_test, y_test)
    print()
    print("For: ", name)
    print("Accuracy: ", current_accuracy)
    print("Precision: ", current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)

    # Calculate and plot the confusion matrix
    current_conf_matrix = confusion_matrix(y_test, clf.predict(X_test))
    plot_confusion_matrix(current_conf_matrix, f'Confusion Matrix for {name}')
# Out:
# For:  LogisticRegression
# Accuracy:  0.823728813559322
# Precision:  0.7727272727272727
# For:  Support_Vector
# Accuracy:  0.6203389830508474
# Precision:  0.0
# For:  DecisionTree
# Accuracy:  0.7898305084745763
# Precision:  0.7155172413793104
# For:  Kneighbors
# Accuracy:  0.6915254237288135
# Precision:  0.6179775280898876
# For:  Random Forest
# Accuracy:  0.8169491525423729
# Precision:  0.8020833333333334
# For:  AdaBoost
# Accuracy:  0.823728813559322
# Precision:  0.7678571428571429
# For:  GradientBoost
# Accuracy:  0.823728813559322
# Precision:  0.8191489361702128
# For:  Beggin
# Accuracy:  0.7932203389830509
# Precision:  0.7524752475247525
# For:  XGB
# Accuracy:  0.8135593220338984
# Precision:  0.7614678899082569

# %% [markdown]
# For:  LogisticRegression
# Accuracy:  0.7898305084745763
# Precision:  0.7403846153846154
#
# For:  Support_Vector
# Accuracy:  0.6203389830508474
# Precision:  0.0
#
#
# For:  DecisionTree
# Accuracy:  0.8
# Precision:  0.7676767676767676
#
#
# For:  Kneighbors
# Accuracy:  0.6677966101694915
# Precision:  0.5875
#
#
# For:  Random Forest
# Accuracy:  0.8033898305084746
# Precision:  0.7872340425531915
#
#
# For:  AdaBoost
# Accuracy:  0.7694915254237288
# Precision:  0.7156862745098039
#
# For:  GradientBoost
# Accuracy:  0.8169491525423729
# Precision:  0.7788461538461539
#
#
#
# For:  Beggin
# Accuracy:  0.823728813559322
# Precision:  0.8061224489795918
#
#
# For:  XGB
# Accuracy:  0.7830508474576271
# Precision:  0.7307692307692307

# %%
train_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    int64
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    int64
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    int64
# dtypes: float64(2), int64(9)
# memory usage: 76.7 KB

# %%
train_file.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64
